# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    'Lamda_MAX_(micrometros)'  'Lamda_MIN_(micrometros)'  'Delta_Lamda_(rmse)'  \
# 0                    5.05158                   0.803457          3.067477e-12
# 1                    5.02937                   0.802888          9.609355e-12
# 2                    4.17790                   0.806160          2.292422e-10
# 3                    5.05163                   0.806750          1.099891e-10
# 4                    5.07467                   0.804772          6.782517e-11
#
#   'Radial Velocity (km s-1)'  'Delta_rv(ABSFERR)'  'Tempeartura_(Kelvin)'  \
# 0              36.4280650000             0.011749             2474.741005
# 1              110.305960000             0.132739             2279.546545
# 2              12.2947000000             0.172684             2345.589069
# 3              17.3472650000             0.116698             2243.766455
# 4              47.2365940000             0.125731             2486.100625
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 281 entries, 0 to 280
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   'Lamda_MAX_(micrometros)'   281 non-null    float64
#  1   'Lamda_MIN_(micrometros)'   281 non-null    float64
#  2   'Delta_Lamda_(rmse)'        281 non-null    float64
#  3   'Radial Velocity (km s-1)'  281 non-null    object
#  4   'Delta_rv(ABSFERR)'         281 non-null    float64
#  5   'Tempeartura_(Kelvin)'      281 non-null    float64
#  6   'Delta_Temperatura'         281 non-null    float64
#  7   'Tipo_de_Estrella'          281 non-null    object
#  8   'Archivo'                   281 non-null    object
# dtypes: float64(6), object(3)
# memory usage: 19.9+ KB

# %%
df.describe()
# Out:
#        'Lamda_MAX_(micrometros)'  'Lamda_MIN_(micrometros)'  \
# count                 281.000000                 281.000000
# mean                    4.330896                   0.812946
# std                     1.002834                   0.024338
# min                     2.410840                   0.801935
# 25%                     4.109770                   0.806027
# 50%                     4.942140                   0.808192
# 75%                     5.033480                   0.810740
# max                     5.456760                   0.935314
#
#        'Delta_Lamda_(rmse)'  'Delta_rv(ABSFERR)'  'Tempeartura_(Kelvin)'  \
# count          2.810000e+02           281.000000              281.000000
# mean           9.457881e-11             0.083719             3694.864973
# std            4.419538e-10             0.059566             2146.068949
# min            6.126425e-16             0.009961             1195.636028
# ...

# %%
df.columns = ['lamda_max', 'lamda_min', 'delta_lamda', 'velocidad_radial', 'delta_rv', 'temperatura', 'delta_temperatura', 'tipo_estrella', 'archivo']

# %%
df.corr()
# Out:
#                    lamda_max  lamda_min  delta_lamda  delta_rv  temperatura  \
# lamda_max           1.000000  -0.308593     0.091960  0.069455     0.097048
# lamda_min          -0.308593   1.000000    -0.029210 -0.235777    -0.145313
# delta_lamda         0.091960  -0.029210     1.000000  0.067526    -0.039418
# delta_rv            0.069455  -0.235777     0.067526  1.000000    -0.077903
# temperatura         0.097048  -0.145313    -0.039418 -0.077903     1.000000
# delta_temperatura   0.100292  -0.029188     0.960615  0.050239     0.182515
#
#                    delta_temperatura
# lamda_max                   0.100292
# lamda_min                  -0.029188
# delta_lamda                 0.960615
# delta_rv                    0.050239
# temperatura                 0.182515
# delta_temperatura           1.000000

# %%
sns.heatmap(df.corr(), cmap="coolwarm", vmin=-1, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df, hue="tipo_estrella", palette="hls")

# %%
df.head()
# Out:
#    lamda_max  lamda_min   delta_lamda velocidad_radial  delta_rv  temperatura  \
# 0    5.05158   0.803457  3.067477e-12    36.4280650000  0.011749  2474.741005
# 1    5.02937   0.802888  9.609355e-12    110.305960000  0.132739  2279.546545
# 2    4.17790   0.806160  2.292422e-10    12.2947000000  0.172684  2345.589069
# 3    5.05163   0.806750  1.099891e-10    17.3472650000  0.116698  2243.766455
# 4    5.07467   0.804772  6.782517e-11    47.2365940000  0.125731  2486.100625
#
#    delta_temperatura tipo_estrella      archivo
# 0       6.483394e-09             C  ./data/C/C1
# 1       1.723268e-08             C  ./data/C/C2
# 2       4.352713e-07             C  ./data/C/C3
# 3       1.911026e-07             C  ./data/C/C4
# 4       1.446738e-07             C  ./data/C/C5

# %%
sns.scatterplot(x=df.tipo_estrella, y=df.temperatura, hue=df.tipo_estrella, palette="hls")
# Out:
# <AxesSubplot:xlabel='tipo_estrella', ylabel='temperatura'>

# %%
sns.scatterplot(x=df.tipo_estrella, y=df.delta_rv, hue=df.tipo_estrella, palette="hls")
# Out:
# <AxesSubplot:xlabel='tipo_estrella', ylabel='delta_rv'>

# %%
sns.scatterplot(x=df.delta_temperatura, y=df.delta_rv, hue=df.tipo_estrella, palette="hls")
# Out:
# <AxesSubplot:xlabel='delta_temperatura', ylabel='delta_rv'>

# %%
sns.scatterplot(x=df.delta_lamda, y=df.delta_rv, hue=df.tipo_estrella, palette="hls")
# Out:
# <AxesSubplot:xlabel='delta_lamda', ylabel='delta_rv'>

# %%
sns.scatterplot(x=df.delta_lamda, y=df.delta_temperatura, hue=df.tipo_estrella, palette="hls")
# Out:
# <AxesSubplot:xlabel='delta_lamda', ylabel='delta_temperatura'>

# %%
sns.distplot(df['lamda_max'])
# Out:
# /Users/douglasdeleon/Documents/DouglasJr/semestre7/Data_Mining/venv/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='lamda_max', ylabel='Density'>

# %%
sns.distplot(df['lamda_min'])
# Out:
# /Users/douglasdeleon/Documents/DouglasJr/semestre7/Data_Mining/venv/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='lamda_min', ylabel='Density'>

# %%
sns.distplot(df['delta_lamda'])
# Out:
# /Users/douglasdeleon/Documents/DouglasJr/semestre7/Data_Mining/venv/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='delta_lamda', ylabel='Density'>

# %%
sns.distplot(df['delta_rv'])
# Out:
# <AxesSubplot:xlabel='delta_rv', ylabel='Density'>

# %%
sns.distplot(df['temperatura'])
# Out:
# /Users/douglasdeleon/Documents/DouglasJr/semestre7/Data_Mining/venv/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='temperatura', ylabel='Density'>

# %%
sns.distplot(df['delta_temperatura'])
# Out:
# /Users/douglasdeleon/Documents/DouglasJr/semestre7/Data_Mining/venv/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='delta_temperatura', ylabel='Density'>
