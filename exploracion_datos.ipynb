# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    'Lamda_MAX_(micrometros)'  ...    'Archivo'
# 0                    5.05158  ...  ./data/C/C1
# 1                    5.02937  ...  ./data/C/C2
# 2                    4.17790  ...  ./data/C/C3
# 3                    5.05163  ...  ./data/C/C4
# 4                    5.07467  ...  ./data/C/C5
#
# [5 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 281 entries, 0 to 280
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   'Lamda_MAX_(micrometros)'   281 non-null    float64
#  1   'Lamda_MIN_(micrometros)'   281 non-null    float64
#  2   'Delta_Lamda_(rmse)'        281 non-null    float64
#  3   'Radial Velocity (km s-1)'  281 non-null    object
#  4   'Delta_rv(ABSFERR)'         281 non-null    float64
#  5   'Tempeartura_(Kelvin)'      281 non-null    float64
#  6   'Delta_Temperatura'         281 non-null    float64
#  7   'Tipo_de_Estrella'          281 non-null    object
#  8   'Archivo'                   281 non-null    object
# dtypes: float64(6), object(3)
# memory usage: 19.9+ KB

# %%
df.describe()
# Out:
#        'Lamda_MAX_(micrometros)'  ...  'Delta_Temperatura'
# count                 281.000000  ...         2.810000e+02
# mean                    4.330896  ...         3.832317e-07
# std                     1.002834  ...         1.792317e-06
# min                     2.410840  ...         6.719151e-13
# 25%                     4.109770  ...         7.684127e-09
# 50%                     4.942140  ...         2.611316e-08
# 75%                     5.033480  ...         7.331608e-08
# max                     5.456760  ...         1.722236e-05
#
# [8 rows x 6 columns]

# %%
df.columns = ['lamda_max', 'lamda_min', 'delta_lamda', 'velocidad_radial', 'delta_rv', 'temperatura', 'delta_temperatura', 'tipo_estrella', 'archivo']

# %%
df.corr()
# Out:
#                    lamda_max  lamda_min  ...  temperatura  delta_temperatura
# lamda_max           1.000000  -0.308593  ...     0.097048           0.100292
# lamda_min          -0.308593   1.000000  ...    -0.145313          -0.029188
# delta_lamda         0.091960  -0.029210  ...    -0.039418           0.960615
# delta_rv            0.069455  -0.235777  ...    -0.077903           0.050239
# temperatura         0.097048  -0.145313  ...     1.000000           0.182515
# delta_temperatura   0.100292  -0.029188  ...     0.182515           1.000000
#
# [6 rows x 6 columns]

# %%
sns.heatmap(df.corr(), cmap="coolwarm", vmin=-1, annot=True)

# %%
sns.pairplot(df, hue="tipo_estrella", palette="hls")

# %%
df.head()
# Out:
#    lamda_max  lamda_min  ...  tipo_estrella      archivo
# 0    5.05158   0.803457  ...              C  ./data/C/C1
# 1    5.02937   0.802888  ...              C  ./data/C/C2
# 2    4.17790   0.806160  ...              C  ./data/C/C3
# 3    5.05163   0.806750  ...              C  ./data/C/C4
# 4    5.07467   0.804772  ...              C  ./data/C/C5
#
# [5 rows x 9 columns]

# %%
sns.scatterplot(x=df.tipo_estrella, y=df.temperatura, hue=df.tipo_estrella, palette="hls")

# %%
sns.scatterplot(x=df.tipo_estrella, y=df.delta_rv, hue=df.tipo_estrella, palette="hls")

# %%
sns.scatterplot(x=df.delta_temperatura, y=df.delta_rv, hue=df.tipo_estrella, palette="hls")

# %%
sns.scatterplot(x=df.delta_lamda, y=df.delta_rv, hue=df.tipo_estrella, palette="hls")

# %%
sns.scatterplot(x=df.delta_lamda, y=df.delta_temperatura, hue=df.tipo_estrella, palette="hls")
